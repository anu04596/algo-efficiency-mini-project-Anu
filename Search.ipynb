# %% [markdown]
# <a href="https://colab.research.google.com/github/anu04596/algo-efficiency-mini-project-Anu/blob/main/Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import random
import matplotlib.pyplot as plt

# %% [markdown]
# Linear Search

# %%
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1

# %% [markdown]
# Binary Search

# %%
def binary_search(arr, target):
    low, high = 0, len(arr) - 1

    while low <= high:
        mid = low+ (high-low) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1

    return -1

# %%
sizes = [100, 500, 1000, 5000, 10000, 20000, 50000]
linear_times = []
binary_times = []

# %%
for n in sizes:
    arr = sorted(random.sample(range(1, n*10), n))
    target = arr[-1]  # worst-case: last element

    # Linear Search timing
    start = time.time()
    linear_search(arr, target)
    end = time.time()
    linear_times.append(end - start)

    # Binary Search timing
    start = time.time()
    binary_search(arr, target)
    end = time.time()
    binary_times.append(end - start)

# %%
plt.figure(figsize=(8,5))
plt.plot(sizes, linear_times, 'r-o', label="Linear Search")
plt.plot(sizes, binary_times, 'b-o', label="Binary Search")
plt.xlabel("Input Size (n)")
plt.ylabel("Execution Time (seconds)")
plt.title("Linear vs Binary Search Performance")
plt.legend()
plt.ylim()
plt.grid(True)
plt.show()
