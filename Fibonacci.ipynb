# %% [markdown]
# <a href="https://colab.research.google.com/github/anu04596/algo-efficiency-mini-project-Anu/blob/main/Fibonacciipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import matplotlib.pyplot as plt

# %% [markdown]
# Without Recursion

# %%
def fibonacci(n):
  if n<=1 :
    return n
  a,b=0,1
  for i in range(n):
    a,b=b,a+b
  return b

# %% [markdown]
# With Recursion

# %%
def fibonacci_rec(n):
  if n<=1:
    return n
  return fibonacci_rec(n-1)+fibonacci_rec(n-2)

# %% [markdown]
# Measuring Time

# %%
def measure_time(func, n_values):
    times = []
    for n in n_values:
        start = time.time()
        func(n)
        end = time.time()
        times.append(end - start)
    return times

# %% [markdown]
# Input Sizes

# %%
n_values_iterative = list(range(1, 2000,200))
n_values_recursive = list(range(1, 40))

# %% [markdown]
# Measure

# %%
times_iterative = measure_time(fibonacci, n_values_iterative)
times_recursive = measure_time(fibonacci_rec, n_values_recursive)
print(times_iterative)
print(times_recursive)
# Out:
# [1.9073486328125e-06, 2.1457672119140625e-05, 5.698204040527344e-05, 6.532669067382812e-05, 6.914138793945312e-05, 6.961822509765625e-05, 8.821487426757812e-05, 0.0001506805419921875, 0.0002155303955078125, 0.000217437744140625]
# [9.5367431640625e-07, 9.5367431640625e-07, 9.5367431640625e-07, 1.1920928955078125e-06, 1.1920928955078125e-06, 2.1457672119140625e-06, 3.5762786865234375e-06, 4.76837158203125e-06, 6.67572021484375e-06, 1.1205673217773438e-05, 2.0265579223632812e-05, 2.9325485229492188e-05, 4.6253204345703125e-05, 7.43865966796875e-05, 0.00013065338134765625, 0.00024819374084472656, 0.00031447410583496094, 0.000606536865234375, 0.001047372817993164, 0.001821756362915039, 0.0025103092193603516, 0.003977060317993164, 0.007747173309326172, 0.009910345077514648, 0.016353607177734375, 0.02419900894165039, 0.04021596908569336, 0.06455302238464355, 0.10306215286254883, 0.16883587837219238, 0.30120849609375, 0.46154212951660156, 0.7152700424194336, 1.1991891860961914, 1.881659984588623, 3.1125009059906006, 6.064095973968506, 8.90643835067749, 14.486696004867554]

# %% [markdown]
# Plot

# %%
plt.figure(figsize=(10,6))
plt.plot(n_values_iterative, times_iterative, label="Iterative", marker='o')
plt.plot(n_values_recursive, times_recursive, label="Recursive", marker='s', color="red")

plt.title("Fibonacci: Iterative vs Recursive Time Complexity")
plt.xlabel("n (Fibonacci term)")
plt.ylabel("Execution Time (seconds)")
plt.ylim(0, 0.01)
plt.legend()
plt.grid(True)
plt.show()
